# %%
import csv
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score
import statsmodels.api as sm
from sklearn.metrics import accuracy_score

# %%
#讀取csv檔
train = pd.read_csv('bank.csv')
# train.to_csv("1_save_test2.csv",index=True)
train.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
train.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
train.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
value_counts = train['y'].value_counts()
value_counts.plot.bar(title = 'y value counts')
#no 根 yes的差距非常大，沒有定期存款的人超級多，資料不平均

# %%
plt.figure(figsize=(15,15))
sns.heatmap(train.corr(),square=True,annot=True,cmap= 'twilight_shifted')
#看相關性

# %%
j_df = pd.DataFrame()

j_df['yes'] = train[train['y'] == 'yes']['job'].value_counts()
j_df['no'] = train[train['y'] == 'no']['job'].value_counts()

j_df.plot.bar(title = 'Job and y')
#有在定期存款的人偏向管理，技術人員，藍領

# %%
j_df = pd.DataFrame()

j_df['yes'] = train[train['y'] == 'yes']['marital'].value_counts()
j_df['no'] = train[train['y'] == 'no']['marital'].value_counts()

j_df.plot.bar(title = 'Marital status and deposit')
#有了家庭的人也比較會買定期存款

# %%
j_df = pd.DataFrame()

j_df['yes'] = train[train['y'] == 'yes']['education'].value_counts()
j_df['no'] = train[train['y'] == 'no']['education'].value_counts()

j_df.plot.bar(title = 'Education and deposit')
#學歷越高的人，越有可能買定期存款

# %%
j_df = pd.DataFrame()

j_df['yes'] = train[train['y'] == 'yes']['contact'].value_counts()
j_df['no'] = train[train['y'] == 'no']['contact'].value_counts()

j_df.plot.bar(title = 'Type of contact and deposit')
#同時利用手機根客戶聯繫會有比較大的機會買定期存款

# %%
label_quality = LabelEncoder()
#轉換成0，1

# %%
train['y'].value_counts()
# Out:
# 0    4000
# 1     521
# Name: y, dtype: int64

# %%
train.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome  y
# 0  cellular   19   oct        79         1     -1         0  unknown  0
# 1  cellular   11   may       220         1    339         4  failure  0
# 2  cellular   16   apr       185         1    330         1  failure  0
# 3   unknown    3   jun       199         4     -1         0  unknown  0
# 4   unknown    5   may       226         1     -1         0  unknown  0

# %%
cols = train.columns
num_cols= train._get_numeric_data().columns #數字列表
cat_cols = list(set(cols) - set(num_cols)) #非數字列表

# %%
train[cat_cols]
# Out:
#      loan  education            job housing default  marital   contact  \
# 0      no    primary     unemployed      no      no  married  cellular
# 1     yes  secondary       services     yes      no  married  cellular
# 2      no   tertiary     management     yes      no   single  cellular
# 3     yes   tertiary     management     yes      no  married   unknown
# 4      no  secondary    blue-collar     yes      no  married   unknown
# ...   ...        ...            ...     ...     ...      ...       ...
# 4516   no  secondary       services     yes      no  married  cellular
# 4517  yes   tertiary  self-employed     yes     yes  married   unknown
# 4518   no  secondary     technician      no      no  married  cellular
# 4519   no  secondary    blue-collar      no      no  married  cellular
# 4520  yes   tertiary   entrepreneur     yes      no   single  cellular
#
#      poutcome month
# 0     unknown   oct
# 1     failure   may
# 2     failure   apr
# 3     unknown   jun
# ...

# %%
train[num_cols]
# Out:
#       age  balance  day  duration  campaign  pdays  previous  y
# 0      30     1787   19        79         1     -1         0  0
# 1      33     4789   11       220         1    339         4  0
# 2      35     1350   16       185         1    330         1  0
# 3      30     1476    3       199         4     -1         0  0
# 4      59        0    5       226         1     -1         0  0
# ...   ...      ...  ...       ...       ...    ...       ... ..
# 4516   33     -333   30       329         5     -1         0  0
# 4517   57    -3313    9       153         1     -1         0  0
# 4518   57      295   19       151        11     -1         0  0
# 4519   28     1137    6       129         4    211         3  0
# 4520   44     1136    3       345         2    249         7  0
#
# [4521 rows x 8 columns]

# %%
train1 = train[cat_cols].apply(LabelEncoder().fit_transform) #轉變成數字

# %%
train1
# Out:
#       loan  education  job  housing  default  marital  contact  poutcome  \
# 0        0          0   10        0        0        1        0         3
# 1        1          1    7        1        0        1        0         0
# 2        0          2    4        1        0        2        0         0
# 3        1          2    4        1        0        1        2         3
# 4        0          1    1        1        0        1        2         3
# ...    ...        ...  ...      ...      ...      ...      ...       ...
# 4516     0          1    7        1        0        1        0         3
# 4517     1          2    6        1        1        1        2         3
# 4518     0          1    9        0        0        1        0         3
# 4519     0          1    1        0        0        1        0         1
# 4520     1          2    2        1        0        2        0         1
#
#       month
# 0        10
# 1         8
# 2         0
# 3         6
# 4         8
# ...

# %%
trainf = train1.join(train[num_cols])

# %%
trainf
# Out:
#       loan  education  job  housing  default  marital  contact  poutcome  \
# 0        0          0   10        0        0        1        0         3
# 1        1          1    7        1        0        1        0         0
# 2        0          2    4        1        0        2        0         0
# 3        1          2    4        1        0        1        2         3
# 4        0          1    1        1        0        1        2         3
# ...    ...        ...  ...      ...      ...      ...      ...       ...
# 4516     0          1    7        1        0        1        0         3
# 4517     1          2    6        1        1        1        2         3
# 4518     0          1    9        0        0        1        0         3
# 4519     0          1    1        0        0        1        0         1
# 4520     1          2    2        1        0        2        0         1
#
#       month  age  balance  day  duration  campaign  pdays  previous  y
# ...

# %%
trainf[trainf.pdays == -1]
# Out:
#       loan  education  job  housing  default  marital  contact  poutcome  \
# 0        0          0   10        0        0        1        0         3
# 3        1          2    4        1        0        1        2         3
# 4        0          1    1        1        0        1        2         3
# 7        0          1    9        1        0        1        0         3
# 8        0          2    2        1        0        1        2         3
# ...    ...        ...  ...      ...      ...      ...      ...       ...
# 4513     0          1    1        0        0        1        0         3
# 4515     0          1    7        1        0        2        0         3
# 4516     0          1    7        1        0        1        0         3
# 4517     1          2    6        1        1        1        2         3
# 4518     0          1    9        0        0        1        0         3
#
#       month  age  balance  day  duration  campaign  pdays  previous  y
# ...

# %%
trainf.pdays.value_counts() #pdays的-1有3705個！！！！
# Out:
# -1      3705
#  182      23
#  183      20
#  363      12
#  92       12
#         ...
#  222       1
#  210       1
#  206       1
#  162       1
#  28        1
# Name: pdays, Length: 292, dtype: int64

# %%
trainf.drop('pdays',axis=1)#於是決定把pdays刪掉
# Out:
#       loan  education  job  housing  default  marital  contact  poutcome  \
# 0        0          0   10        0        0        1        0         3
# 1        1          1    7        1        0        1        0         0
# 2        0          2    4        1        0        2        0         0
# 3        1          2    4        1        0        1        2         3
# 4        0          1    1        1        0        1        2         3
# ...    ...        ...  ...      ...      ...      ...      ...       ...
# 4516     0          1    7        1        0        1        0         3
# 4517     1          2    6        1        1        1        2         3
# 4518     0          1    9        0        0        1        0         3
# 4519     0          1    1        0        0        1        0         1
# 4520     1          2    2        1        0        2        0         1
#
#       month  age  balance  day  duration  campaign  previous  y
# ...

# %%
x = trainf.drop('y',axis=1)
y = trainf['y']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3,random_state=101)

# %%
print("Shape of x_train: ",x_train.shape)
print("Shape of x_test: ", x_test.shape)
print("Shape of y_train: ",y_train.shape)
print("Shape of y_test",y_test.shape)
# Out:
# Shape of x_train:  (3164, 16)
# Shape of x_test:  (1357, 16)
# Shape of y_train:  (3164,)
# Shape of y_test (1357,)

# %%
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn import metrics
from sklearn import svm

SV = svm.SVC()
SV.fit(x_train, y_train)

print("Test set accuracy: {:.6f}".format(SV.score(x_test, y_test)))

# 嘗試預測 x, y

expected = y_test
predicted = SV.predict(x_test)

print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# Test set accuracy: 0.890936
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94      1202
#            1       0.59      0.14      0.23       155
#
#     accuracy                           0.89      1357
#    macro avg       0.75      0.56      0.59      1357
# weighted avg       0.86      0.89      0.86      1357
#
# [[1187   15]
#  [ 133   22]]

# %%
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier

DC = DecisionTreeClassifier()
DC.fit(x_train, y_train)

print("Test set accuracy: {:.6f}".format(DC.score(x_test, y_test)))

# 嘗試預測 x, y

expected = y_test
predicted = DC.predict(x_test)

print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# Test set accuracy: 0.859248
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      1202
#            1       0.39      0.39      0.39       155
#
#     accuracy                           0.86      1357
#    macro avg       0.65      0.66      0.66      1357
# weighted avg       0.86      0.86      0.86      1357
#
# [[1105   97]
#  [  94   61]]

# %%
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier

RC = RandomForestClassifier()
RC.fit(x_train, y_train)

print("Test set accuracy: {:.6f}".format(RC.score(x_test, y_test)))

# 嘗試預測 x, y

expected = y_test
predicted = RC.predict(x_test)

print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# Test set accuracy: 0.895357
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      1202
#            1       0.58      0.29      0.39       155
#
#     accuracy                           0.90      1357
#    macro avg       0.75      0.63      0.67      1357
# weighted avg       0.88      0.90      0.88      1357
#
# [[1170   32]
#  [ 110   45]]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

param = {'n_estimators': [120,300,500],
         'max_depth': [1,5,8]}

grid = GridSearchCV(RandomForestClassifier(), param)
grid.fit(x_train, y_train)
grid.cv_results_['mean_test_score'], grid.best_params_, grid.best_score_
# Out:
# (array([0.88432369, 0.88432369, 0.88432369, 0.89032885, 0.8900129 ,
#         0.88938149, 0.89190913, 0.89507219, 0.89633651]),
#  {'max_depth': 8, 'n_estimators': 500},
#  0.8963365128881957)
